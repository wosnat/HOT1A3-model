# %%
import pandas as pd
import matplotlib.pyplot as plt
import cobra
import numpy as np
import seaborn as sns
import itertools
from matplotlib.colors import LogNorm, Normalize

# %%
import os
modelseed_dpath = os.path.join('..', '..', '..', 'ModelSEEDDatabase', 'Biochemistry',  )
os.listdir(modelseed_dpath)
# Out:
# ['Aliases',
#  'compounds.json',
#  'COMPOUNDS.md',
#  'compounds.tsv',
#  'Pathways',
#  'reactions.json',
#  'REACTIONS.md',
#  'reactions.tsv',
#  'README.md',
#  'Structures',
#  'Thermodynamics']

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'generate kbase medias.ipynb',
#  'Glucose_minimal.tsv',
#  'HOT1A3_medias_for_kbase.xlsx',
#  'KBASE_MEDIAS']

# %%
modelseed_media_fpath = os.path.join('..', '..', '..', 'ModelSEEDDatabase', 'Media', 'KBaseMedia.cpd'  )
kbase_exchange_df = pd.read_csv(modelseed_media_fpath, names=['id'])
kbase_exchange_df['kbase_exchange'] = True

# %%
glucose_min_df = pd.read_csv( 'Glucose_minimal.tsv', sep='\t')
glucose_min_df['glucose_min'] = True

# %%
glucose_min_df
# Out:
#    compounds       name  formula  minFlux  maxFlux  concentration  glucose_min
# 0   cpd00149       Co2+       Co     -100      100          0.001         True
# 1   cpd00099        Cl-       Cl     -100      100          0.001         True
# 2   cpd00067         H+        H     -100      100          0.001         True
# 3   cpd00063       Ca2+       Ca     -100      100          0.001         True
# 4   cpd00058       Cu2+       Cu     -100      100          0.001         True
# 5   cpd00048    Sulfate      O4S     -100      100          0.001         True
# 6   cpd00034       Zn2+       Zn     -100      100          0.001         True
# 7   cpd00030       Mn2+       Mn     -100      100          0.001         True
# 8   cpd00013        NH3      H4N     -100      100          0.001         True
# 9   cpd00009  Phosphate     HO4P     -100      100          0.001         True
# 10  cpd00001        H2O      H2O     -100      100          0.001         True
# 11  cpd00007         O2       O2     -100       10          0.001         True
# 12  cpd00205         K+        K     -100      100          0.001         True
# 13  cpd00254         Mg       Mg     -100      100          0.001         True
# 14  cpd00971        Na+       Na     -100      100          0.001         True
# 15  cpd10515       Fe+2       Fe     -100      100          0.001         True
# 16  cpd10516       Fe+3       Fe     -100      100          0.001         True
# 17  cpd11574  Molybdate     MoO4     -100      100          0.001         True
# 18  cpd00244       Ni2+       Ni     -100      100          0.001         True
# 19  cpd00027  D-Glucose  C6H12O6     -100        5          0.001         True

# %%
compound_df = pd.read_csv(os.path.join(modelseed_dpath, 'compounds.tsv'), sep='\t')
# Out:
# C:\Users\Osnat\AppData\Local\Temp\ipykernel_9236\1181313684.py:1: DtypeWarning: Columns (4,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   compound_df = pd.read_csv(os.path.join(modelseed_dpath, 'compounds.tsv'), sep='\t')

# %%
compound_df = pd.merge(compound_df, kbase_exchange_df, on='id', how='left')

# %%
compound_df = pd.merge(compound_df, glucose_min_df[['compounds', 'glucose_min']], left_on='id', right_on='compounds', how='left')

# %%
compound_df.loc[compound_df.kbase_exchange.isna(), 'kbase_exchange'] = False

# %%
compound_df.loc[compound_df.glucose_min.isna(), 'glucose_min'] = False

# %% [raw]
# compound_df.loc[compound_df.kbase_exchange].to_excel('kbase_media.xlsx', )

# %% [markdown]
# # Generate media files

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'generate kbase medias.ipynb',
#  'Glucose_minimal.tsv',
#  'HOT1A3_medias_for_kbase.xlsx',
#  'KBASE_MEDIAS']

# %%
df = pd.read_excel( 'HOT1A3_medias_for_kbase.xlsx')

# %%
glucose_min_df
# Out:
#    compounds       name  formula  minFlux  maxFlux  concentration  glucose_min
# 0   cpd00149       Co2+       Co     -100      100          0.001         True
# 1   cpd00099        Cl-       Cl     -100      100          0.001         True
# 2   cpd00067         H+        H     -100      100          0.001         True
# 3   cpd00063       Ca2+       Ca     -100      100          0.001         True
# 4   cpd00058       Cu2+       Cu     -100      100          0.001         True
# 5   cpd00048    Sulfate      O4S     -100      100          0.001         True
# 6   cpd00034       Zn2+       Zn     -100      100          0.001         True
# 7   cpd00030       Mn2+       Mn     -100      100          0.001         True
# 8   cpd00013        NH3      H4N     -100      100          0.001         True
# 9   cpd00009  Phosphate     HO4P     -100      100          0.001         True
# 10  cpd00001        H2O      H2O     -100      100          0.001         True
# 11  cpd00007         O2       O2     -100       10          0.001         True
# 12  cpd00205         K+        K     -100      100          0.001         True
# 13  cpd00254         Mg       Mg     -100      100          0.001         True
# 14  cpd00971        Na+       Na     -100      100          0.001         True
# 15  cpd10515       Fe+2       Fe     -100      100          0.001         True
# 16  cpd10516       Fe+3       Fe     -100      100          0.001         True
# 17  cpd11574  Molybdate     MoO4     -100      100          0.001         True
# 18  cpd00244       Ni2+       Ni     -100      100          0.001         True
# 19  cpd00027  D-Glucose  C6H12O6     -100        5          0.001         True

# %%
glucose_min_df.head()
# Out:
#   compounds  name formula  minFlux  maxFlux  concentration  glucose_min
# 0  cpd00149  Co2+      Co     -100      100          0.001         True
# 1  cpd00099   Cl-      Cl     -100      100          0.001         True
# 2  cpd00067    H+       H     -100      100          0.001         True
# 3  cpd00063  Ca2+      Ca     -100      100          0.001         True
# 4  cpd00058  Cu2+      Cu     -100      100          0.001         True

# %%
df['compounds'] = df['id']
df['minFlux'] = -100
df['maxFlux']= 100
df['concentration'] = 0.001

# %%
df.head().T
# Out:
#                                                                    0  \
# PROMM_glycerol                                                   1.0
# PROMM_lactate                                                    1.0
# PROMM_acetate                                                    1.0
# PROMM_pyruvate                                                   1.0
# PROMM                                                            1.0
# PRO99                                                            1.0
# HMB_neg                                                          1.0
# HMBaa                                                            1.0
# HMBamisug                                                        1.0
# HMBntrl                                                          1.0
# HMBoligo                                                         1.0
# HMBorg                                                           1.0
# HMBlips                                                          1.0
# MMB_neg                                                          1.0
# MMB_pyruvate                                                     1.0
# MMB_aa                                                           1.0
# id                                                          cpd00034
# abbreviation                                                     zn2
# name                                                            Zn2+
# formula                                                           Zn
# mass                                                            65.0
# source                                              Primary Database
# inchikey                                 PTFCDOFLOPIGGS-UHFFFAOYSA-N
# charge                                                             2
# is_core                                                            1
# is_obsolete                                                        0
# linked_compound                                                  NaN
# is_cofactor                                                        0
# deltag                                                    10000000.0
# deltagerr                                                 10000000.0
# pka                                                         1:1:3.09
# pkb                                                              NaN
# abstract_compound                                                NaN
# comprised_of                                                     NaN
# aliases            Name: Zinc; Zinc cation; Zinc ion; Zn; Zn(II);...
# smiles                                                        [Zn+2]
# notes                                                             GC
# kbase_exchange                                                  True
# compounds                                                   cpd00034
# glucose_min                                                     True
# minFlux                                                         -100
# maxFlux                                                          100
# concentration                                                  0.001
#
#                                                                    1  \
# PROMM_glycerol                                                   NaN
# PROMM_lactate                                                    NaN
# PROMM_acetate                                                    NaN
# PROMM_pyruvate                                                   NaN
# PROMM                                                            NaN
# PRO99                                                            NaN
# HMB_neg                                                          NaN
# HMBaa                                                            NaN
# HMBamisug                                                        NaN
# HMBntrl                                                          NaN
# HMBoligo                                                         NaN
# HMBorg                                                           NaN
# HMBlips                                                          NaN
# MMB_neg                                                          NaN
# MMB_pyruvate                                                     NaN
# MMB_aa                                                           NaN
# id                                                          cpd00003
# abbreviation                                                     nad
# name                                                             NAD
# formula                                                C21H26N7O14P2
# mass                                                           662.0
# source                                              Primary Database
# inchikey                                 BAWFJGJZGIEFAR-NNYOXOHSSA-M
# charge                                                            -1
# is_core                                                            1
# is_obsolete                                                        0
# linked_compound                                                  NaN
# is_cofactor                                                        0
# deltag                                                       -286.41
# deltagerr                                                       1.59
# pka                1:6:11.94;1:17:1.85;1:18:2.28;1:25:11.38;1:35:...
# pkb                1:6:-4.22;1:35:-3.85;1:37:-1.05;1:41:4.93;1:43...
# abstract_compound                                                NaN
# comprised_of                                                     NaN
# aliases            Name: DPN; DPN+; DPN-ox; Diphosphopyridine nuc...
# smiles             NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...
# notes                                                      GC|EQ|EQU
# kbase_exchange                                                  True
# compounds                                                   cpd00003
# glucose_min                                                    False
# minFlux                                                         -100
# maxFlux                                                          100
# concentration                                                  0.001
#
#                                                                    2  \
# PROMM_glycerol                                                   NaN
# PROMM_lactate                                                    NaN
# PROMM_acetate                                                    NaN
# PROMM_pyruvate                                                   NaN
# PROMM                                                            NaN
# PRO99                                                            NaN
# HMB_neg                                                          NaN
# HMBaa                                                            NaN
# HMBamisug                                                        NaN
# HMBntrl                                                          NaN
# HMBoligo                                                         NaN
# HMBorg                                                           NaN
# HMBlips                                                          NaN
# MMB_neg                                                          NaN
# MMB_pyruvate                                                     NaN
# MMB_aa                                                           NaN
# id                                                          cpd00006
# abbreviation                                                    nadp
# name                                                            NADP
# formula                                                C21H25N7O17P3
# mass                                                           741.0
# source                                              Primary Database
# inchikey                                 XJLXINKUBYWONI-NNYOXOHSSA-K
# charge                                                            -3
# is_core                                                            1
# is_obsolete                                                        0
# linked_compound                                                  NaN
# is_cofactor                                                        0
# deltag                                                       -498.36
# deltagerr                                                       1.63
# pka                1:18:0.90;1:19:5.78;1:26:3.26;1:30:0.66;1:47:1...
# pkb                                  1:11:-7.46;1:12:-1.06;1:22:4.87
# abstract_compound                                                NaN
# comprised_of                                                     NaN
# aliases            Name: NADP; NADP(+); NADP+; NADP-ox; NADP-oxid...
# smiles             NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(...
# notes                                                      GC|EQ|EQU
# kbase_exchange                                                  True
# compounds                                                   cpd00006
# glucose_min                                                    False
# minFlux                                                         -100
# maxFlux                                                          100
# concentration                                                  0.001
#
#                                                                    3  \
# PROMM_glycerol                                                   NaN
# PROMM_lactate                                                    NaN
# PROMM_acetate                                                    NaN
# PROMM_pyruvate                                                   NaN
# PROMM                                                            NaN
# PRO99                                                            NaN
# HMB_neg                                                          NaN
# HMBaa                                                            NaN
# HMBamisug                                                        NaN
# HMBntrl                                                          NaN
# HMBoligo                                                         NaN
# HMBorg                                                           NaN
# HMBlips                                                          NaN
# MMB_neg                                                          NaN
# MMB_pyruvate                                                     NaN
# MMB_aa                                                           NaN
# id                                                          cpd00010
# abbreviation                                                     coa
# name                                                             CoA
# formula                                               C21H32N7O16P3S
# mass                                                           764.0
# source                                              Primary Database
# inchikey                                 RGJOEKWQDUBAIZ-IBOSZNHHSA-J
# charge                                                            -4
# is_core                                                            1
# is_obsolete                                                        0
# linked_compound                                                  NaN
# is_cofactor                                                        0
# deltag                                                       -429.53
# deltagerr                                                       1.87
# pka                1:22:0.92;1:23:5.94;1:26:0.83;1:30:3.27;1:48:1...
# pkb                                    1:8:-7.46;1:9:-1.06;1:17:4.89
# abstract_compound                                                NaN
# comprised_of                                                     NaN
# aliases            Name: CoA; CoA-SH; Coenzyme A; CoenzymeA; Coen...
# smiles             CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H]...
# notes                                                      GC|EQ|EQU
# kbase_exchange                                                  True
# compounds                                                   cpd00010
# glucose_min                                                    False
# minFlux                                                         -100
# maxFlux                                                          100
# concentration                                                  0.001
#
#                                                                    4
# PROMM_glycerol                                                   NaN
# PROMM_lactate                                                    NaN
# PROMM_acetate                                                    NaN
# PROMM_pyruvate                                                   NaN
# PROMM                                                            NaN
# PRO99                                                            NaN
# HMB_neg                                                          NaN
# HMBaa                                                            NaN
# HMBamisug                                                        NaN
# HMBntrl                                                          NaN
# HMBoligo                                                         NaN
# HMBorg                                                           NaN
# HMBlips                                                          NaN
# MMB_neg                                                          NaN
# MMB_pyruvate                                                     NaN
# MMB_aa                                                           NaN
# id                                                          cpd00011
# abbreviation                                                     co2
# name                                                             CO2
# formula                                                          CO2
# mass                                                            44.0
# source                                              Primary Database
# inchikey                                 CURLTUGMZLYLDI-UHFFFAOYSA-N
# charge                                                             0
# is_core                                                            1
# is_obsolete                                                        0
# linked_compound                                                  NaN
# is_cofactor                                                        0
# deltag                                                        -92.26
# deltagerr                                                       0.71
# pka                                                              NaN
# pkb                                                              NaN
# abstract_compound                                                NaN
# comprised_of                                                     NaN
# aliases            Name: CO2; Carbon dioxide; carbon dioxide; car...
# smiles                                                         O=C=O
# notes                                                      GC|EQ|EQU
# kbase_exchange                                                  True
# compounds                                                   cpd00011
# glucose_min                                                    False
# minFlux                                                         -100
# maxFlux                                                          100
# concentration                                                  0.001

# %% [raw]
# os.mkdir('KBASE_MEDIAS',)

# %% [markdown]
# Use from Elena’s media:
#
# HMB—(does not grow)
#
# Oligo
#
# Aa (with and without vitamins, based on Waseem’s media)
#
# Aminosugars
#
#
#
# From waseems experiments – pyruvate (with and/or without vitamins, wait for reply to email)
#
#
#
# From Eddie’s: ProMM versions (with vitamins)

# %%
medias_list =[
    'PROMM_glycerol', 'PROMM_lactate', 'PROMM_acetate', 'PROMM_pyruvate', 'PROMM', 'PRO99', 
    'HMB_neg', 'HMBaa', 'HMBamisug', 'HMBoligo', 
    #'HMBntrl', 'HMBacdsug', 'HMBorg', 'HMBlips', 
    'MMB_neg', 'MMB_pyruvate','MMB_aa',
]

# %%
medias_growth_list = {
    'PROMM_glycerol' : 1 , 
    'PROMM_lactate' : 1, 
    'PROMM_acetate' : 1, 
    'PROMM_pyruvate' : 1, 
    'PROMM' : 1, 
    'PRO99' : 0, 
    'HMB_neg' : 0, 
    'HMBaa' : 1, 
    'HMBamisug' : 1, 
    'HMBoligo' : 1, 
    #'HMBntrl', 'HMBacdsug', 'HMBorg', 'HMBlips', 
    'MMB_neg' : 0, 
    'MMB_pyruvate' : 1,
    'MMB_aa' : 1,
}

# %%
df.columns
# Out:
# Index(['PROMM_glycerol', 'PROMM_lactate', 'PROMM_acetate', 'PROMM_pyruvate',
#        'PROMM', 'PRO99', 'HMB_neg', 'HMBaa', 'HMBamisug', 'HMBntrl',
#        'HMBoligo', 'HMBorg', 'HMBlips', 'MMB_neg', 'MMB_pyruvate', 'MMB_aa',
#        'id', 'abbreviation', 'name', 'formula', 'mass', 'source', 'inchikey',
#        'charge', 'is_core', 'is_obsolete', 'linked_compound', 'is_cofactor',
#        'deltag', 'deltagerr', 'pka', 'pkb', 'abstract_compound',
#        'comprised_of', 'aliases', 'smiles', 'notes', 'kbase_exchange',
#        'compounds', 'glucose_min', 'minFlux', 'maxFlux', 'concentration'],
#       dtype='object')

# %%
glucose_min_df.columns
# Out:
# Index(['compounds', 'name', 'formula', 'minFlux', 'maxFlux', 'concentration',
#        'glucose_min'],
#       dtype='object')

# %%
media_file_columns = ['compounds', 'name', 'formula', 'minFlux', 'maxFlux', 'concentration']

# %%
media_file_columns = ['compounds', 'name', 'formula', 'minFlux', 'maxFlux', 'concentration']    
for m in medias_list:
    fname = os.path.join('KBASE_MEDIAS', f'{m}.xlsx')
    df.loc[~df[m].isna(), 'maxFlux'] = df.loc[~df[m].isna(), m]
    df.loc[~df[m].isna() & df[m].isin([1]), 'maxFlux'] = 100
    df.loc[~df[m].isna(), media_file_columns].to_excel(fname, sheet_name='MediaCompounds', index=False)

# %% [markdown]
# # phenotype file

# %% [raw]
# phenotype_columns = [
#     'Media', 'geneko', 'mediaws',
#     'addtlCpd',
#     #'Addtl compound bounds','Custom reaction bounds',
#     'Growth']

# %%
phenotype_columns = [
    'geneko', 'mediaws', 'media', 'addtlCpd',
    'addtlCpdBounds','customReactionBounds', 'growth'
                    ]

#none	janakakbase:1441216712744	C-D-Glucose	none			0

# %%
pdf = pd.DataFrame([{'media': f'{i}_media', 'growth': medias_growth_list[i]} for i in medias_growth_list])

# %%
pdf['geneko'] = 'none'
pdf['mediaws'] = 'osnat_weissberg:narrative_1685348220740'
pdf['addtlCpd'] = 'none'
pdf['addtlCpdBounds'] = ''
pdf['customReactionBounds'] = ''

# %%
pdf[phenotype_columns]
# Out:
#    geneko                                  mediaws                 media  \
# 0    none  osnat_weissberg:narrative_1685348220740  PROMM_glycerol_media
# 1    none  osnat_weissberg:narrative_1685348220740   PROMM_lactate_media
# 2    none  osnat_weissberg:narrative_1685348220740   PROMM_acetate_media
# 3    none  osnat_weissberg:narrative_1685348220740  PROMM_pyruvate_media
# 4    none  osnat_weissberg:narrative_1685348220740           PROMM_media
# 5    none  osnat_weissberg:narrative_1685348220740           PRO99_media
# 6    none  osnat_weissberg:narrative_1685348220740         HMB_neg_media
# 7    none  osnat_weissberg:narrative_1685348220740           HMBaa_media
# 8    none  osnat_weissberg:narrative_1685348220740       HMBamisug_media
# 9    none  osnat_weissberg:narrative_1685348220740        HMBoligo_media
# 10   none  osnat_weissberg:narrative_1685348220740         MMB_neg_media
# 11   none  osnat_weissberg:narrative_1685348220740    MMB_pyruvate_media
# 12   none  osnat_weissberg:narrative_1685348220740          MMB_aa_media
#
#    addtlCpd addtlCpdBounds customReactionBounds  growth
# 0      none                                           1
# 1      none                                           1
# 2      none                                           1
# 3      none                                           1
# 4      none                                           1
# 5      none                                           0
# 6      none                                           0
# 7      none                                           1
# 8      none                                           1
# 9      none                                           1
# 10     none                                           0
# 11     none                                           1
# 12     none                                           1

# %%
fname = os.path.join('KBASE_MEDIAS', 'HOT1A3_phenotypes.xlsx')
pdf[phenotype_columns].to_csv(fname, sep='\t', index=False)
